# %%
import os
import pytesseract
from pdf2image import convert_from_path
import requests
import json
from sentence_transformers import SentenceTransformer
import re
import weaviate
from weaviate import client
import weaviate.classes as wvc
from weaviate.classes.config import Property, DataType
import ollama
from weaviate.util import generate_uuid5
import Levenshtein

# %%
# Initialize SentenceTransformer model
model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')

# Set directory containing PDFs
pdf_directory = "C:/Users/AbhinavKasubojula/OneDrive - Kenall Inc/Desktop/code/docs/"

# Ollama API details (if needed for later use)
url = "http://localhost:11434/api/generate"
headers = {"Content-Type": "application/json"}

# %%
# Compute embeddings for documents
def compute_embeddings(documents):
    embeddings = model.encode(documents, convert_to_tensor=False)
    return embeddings

# %%
# Extract text from a PDF using OCR
def extract_text_from_pdf(pdf_path):
    try:
        images = convert_from_path(pdf_path)  # Convert PDF to images
        text = ""
        for page_num, image in enumerate(images):
            text += pytesseract.image_to_string(image)  # OCR on the image
            print(f"Extracted text from page {page_num + 1} of {os.path.basename(pdf_path)}...")
        return text
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {e}")
        return None

# %%
import re

def text_to_dict(text):
    result = {}
    current_key = None
    
    # Split text into lines
    lines = text.strip().split("\n")
    
    # Check if the first line looks like an unwanted heading
    if re.match(r"^(Here is a summary|Summary of)", lines[0], re.IGNORECASE):
        lines = lines[1:]  # Skip the first line if it's an unwanted heading

    for line in lines:
        if ":" in line:  # Line contains a key-value pair
            key, value = line.split(":", 1)
            current_key = key.strip()
            result[current_key] = value.strip()
        else:
            if current_key:  # Append to the previous key's value
                result[current_key] += " " + line.strip()
    
    return result

# %%
def summarize_text_with_ollama(text):
    prompt = f"""
    you are expert in summarizing and sagrigating things. licenses need to be clearly mentioned in licenses category itself. you should get company's name very clearly and get every time in same way.
    structure to get Summarized resume and highlight main points specifically.
    - Name
    - education qualification(you are able to find at name ending (like PE, BA, etc..,))
    - Role
    - Licenses
    - company
    - Qualifications
    - Experience
    - Projects he/she worked before
    - Roles and Responsibilities

    keep headings as it is. for my future reference
    Resume Text:
    {text}
    """
    data = {"model": "llama3.2-vision:latest", "prompt": prompt, "stream": False}
    response = requests.post(url, headers=headers, data=json.dumps(data))
    
    response_json = response.json()

    text = response_json.get("response", "No response found")
    unwanted_prefix = "Here is a summary of the resume:"
    if text.startswith(unwanted_prefix):
        text = text[len(unwanted_prefix):].strip()
    return text

# %%
# Function to clean text
def clean_text(text):
    """Remove asterisks and trim whitespace from the given text."""
    return re.sub(r"\*{1,}", "", text).strip()

# Normalize the dictionary
def normalize_data(data):
    """
    Normalize dictionary keys and values by removing unwanted characters and whitespace.
    """
    normalized_data = []
    for record in data:
        if isinstance(record, dict):
            normalized_record = {clean_text(key): clean_text(value) for key, value in record.items()}
            normalized_data.append(normalized_record)
        else:
            print(f"Warning: Expected a dictionary but got {type(record)}")
    return normalized_data

# %%
# Process each PDF, extract text, summarize, and store in Weaviate
def process(sum_dict, emb, summary_text):
    pdf_files = [f for f in os.listdir(pdf_directory) if f.endswith(".pdf")]
    for pdf_file in pdf_files:
        pdf_path = os.path.join(pdf_directory, pdf_file)
        print(f"Processing: {pdf_file}")
        
        # Extract text from the PDF
        text = extract_text_from_pdf(pdf_path)
        if text:
            # Summarize the extracted text
            summary1 = clean_text(text)
            summary = summarize_text_with_ollama(summary1)
            summary = clean_text(summary)
            summary_dict= text_to_dict(summary)
            print(summary_dict)
            

            # Generate vector embedding
            embedding = compute_embeddings([summary1])[0]           
            # Store data in Weaviate
            #store_in_weaviate(summary, embedding,collection_name)
        sum_dict.append(summary_dict)
        emb.append(embedding)
        summary_text.append(summary)

    return(sum_dict, emb, summary_text)

# %% [markdown]
# process starts here

# %%
# Run the process
sum_dict=[]
embeddings =[]
summary_text =[]
sum_dict, embeddings, summary_text = process(sum_dict, embeddings, summary_text)
#
for i in range(len(sum_dict)):
    sum_dict[i]["vector"] = embeddings[i].tolist()
    sum_dict[i]["summary"] = summary_text[i]
# Out:
# Processing: page_1 (2).pdf
# Extracted text from page 1 of page_1 (2).pdf...
# {'Here is the summarized version of the resume': ' ', 'Name': 'Kris D. Prasad', 'Role': 'Program/Project Manager ', 'Company': 'Kenall-Hana JV, LLC', 'Location': 'Meridian, MS', 'Education': ' - M.S., Civil Engineering (1992) ', 'Licenses': '', '- P.E. (Civil)': 'TX #91952, LA #34186, NM #20737, PR #28316 ', 'Qualifications': ' - Over 29 years of professional engineering and management experience - Currently serving as task order manager for USACE Fort Worth and Tulsa Districts - Experience includes over 1,000 projects with a value of over $100M - Member of SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ', 'Experience': ' - Program/Project Manager at Kenall-Hana JV, LLC for various federal, state, municipal, and local programs - Task order manager for USACE Fort Worth and Tulsa Districts on civil works and military projects - Managed contracts, coordinated with USACE and subcontractors, and prepared full construction plans ', 'Projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, 2002, and 2006', 'Construction': '2019', 'Cost': '$890K', 'Professional Services': '2020, Construction: 2021', 'Note': 'I have kept the same format as requested, with clear headings and concise summaries of each section.'}
# Processing: page_1.pdf
# Extracted text from page 1 of page_1.pdf...
# {'Here is a summarized version of the resume': ' ', 'Name': 'Kris D. Prasad, PE ', 'Education Qualification': 'MS, Civil Engineering (1992) ', 'Role': 'Program Manager/Senior Structural Engineer ', 'Licenses': ' ', 'PE (Civil)': 'TX #91952 (2003), LA #34186, NM #20737, PR# 28316 Other professional registrations not specified ', 'Company': 'SAT-Kenall JV, Houston, TX ', 'Qualifications': '  Over 29 years of professional engineering and management experience Experience with various federal, state, municipal, and local programs Currently serving as Program Manager for USACE Fort Worth and Tulsa Districts Previously served as task order manager for two NAVFAC Southeast projects Member of organizations such as SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ', 'Experience': '  Program Manager/Senior Structural Engineer at SAT-Kenall JV (20 years) Experience with over 1000 projects worth over $100M Managed various civil works and military projects for USACE Fort Worth and Tulsa Districts Performed contract management, coordinated with USACE and subcontractors, and ensured timely submission of deliverables ', 'Projects': ' ', '1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615': 'Program Manager/Senior Structural Engineer (2002-2022) Renovated five historical buildings for functional administrative office space', 'Cost': '$3.8M', '2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot': 'Program Manager/Senior Structural Engineer (2021-2022) Managed 27 facility projects including major renovations to a warehouse and fire station', '3. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood': 'Program Manager/Senior Structural Engineer (2019-2022) Designed 4 separate 100% plans & specifications packages for each battalion TEMF', '4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base': 'Program Manager/Senior Structural Engineer (2019-2022) Renovated the entire 3rd floor of B499, HQ at Air Force Personnel Center'}
# Processing: page_2.pdf
# Extracted text from page 1 of page_2.pdf...
# {'Here is the summarized resume for Srujan Chikyala': ' ', 'Name': 'Srujan Chikyala', 'Role': 'Project Manager', 'Education': '', '- Degree': 'MS, Civil Engineering', '- Specialization': '', '- Year': '2008 ', 'Licenses': ' ', 'PE (Civil)': 'TX #122374 (2015) ', 'Company': 'SAT-Kenall JV', 'Location': 'Randolph Air Force Base, TX', 'Qualifications': '  Provides 13 years of experience leading DB and DBB RFP packages for MILCON and SRM projects at USACE and NAVFAC military facilities and civil works projects for USACE, USDA-NRCS, IBWC, and US Fish & Wildlife Service. Served as a Project Manager on about 75+ engineering projects for federal, public works and public entities that include military facilities, utilities, drainage structures, roadways, bridges, dams, levees, facilities, and other flood control structures for various federal clients. ', 'Experience': '  Project Manager', 'Years of Experience': '13 ', 'Projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, and others', 'Year Completed': '2019-2022', 'Brief Description': 'Renovated the entire 3rd floor of B499, HQ, at Air Force Personnel Center. Cost: $3.8M. ', 'Note': "The provided information is based on the text and might not be a comprehensive summary of Srujan Chikyala's resume or experience."}
# Processing: page_3.pdf
# Extracted text from page 1 of page_3.pdf...
# {'Here is the summarized resume in the required format': ' ', 'Name': 'Brett Witte, PE ', 'Education Qualification': 'BS, Civil Engineering (2005) ', 'Role': 'Project Manager / Civil Engineer ', 'Licenses': ' ', 'PE (Civil)': 'FL #70720 (2010)', 'Current Professional Registration (State and Discipline)': 'Not specified ', 'Company': 'SAI-Kenall JV, Orlando, FL ', 'Qualifications': '  Over 18 years of experience in conducting engineering design, analysis, calculations, and developing technical specifications for civil infrastructure design projects Skilled at H&H modeling using numerous programs, civil infrastructure design, construction plans production using MicroStation and AutoCAD, quantity take-offs, cost estimates, construction phase support and as-built certifications ', 'Experience': '  1. Project Manager / Civil Engineer, Paint and Sandblast Facility, USCG Miami Station, FL (2021) Coordinated between disciplines Led civil design through 65%, 95%, and 100% design documents Attended design review meetings and prepared materials 2. Project Manager / Civil Engineer, Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019) Coordinated between disciplines Designed engineer for preparation of construction plans 3. Project Manager / Civil Engineer, CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021) Coordinated between disciplines Designed engineer for preparation of construction plans 4. Civil Engineer, USACE Fort Worth District - A-E Services for Red River Army Depot — Install Security Fences and Repair Buildings, Texarkana, TX (2019-2020) Performed QC of 65%, 95%, and 100% design documents ', 'Projects': '  1. Paint and Sandblast Facility, USCG Miami Station, FL 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL 3. CES and FES Warehouses, MacDill AFB, Tampa, FL 4. Security Fences and Repair Buildings, Texarkana, TX ', 'Roles and Responsibilities': '  Conducted engineering design, analysis, calculations, and developed technical specifications for civil infrastructure design projects Coordinated between disciplines Led civil design through 65%, 95%, and 100% design documents Attended design review meetings and prepared materials Performed QC of 65%, 95%, and 100% design documents'}
# Processing: page_4.pdf
# Extracted text from page 1 of page_4.pdf...
# {'Here is the summarized resume for Robert Morris': ' ', 'Name': 'Robert Morris, AIA, RID DQC Manager', 'Education Qualification': 'BA, Architectural Design, 1981 ', 'Role': 'DQC Manager, Architect, and Innovator ', 'Licenses': '', 'Registered Architect': 'TX #12112 (1987)', 'Registered Interior Designer': 'TX # 1985 (1993) ', 'Company': 'SAI-Kenall JV', 'Location': 'Houston, TX ', 'Qualifications': '  Experienced with a wide range of building projects and systems Skilled in master planning, programming, and design of architectural projects Performed over 100 detailed Facility Condition Assessments (FCAs) over the past fifteen years ', 'Experience': ' ', 'DQC Manager for various projects including': ' + USACE Fort Worth District - Renovation of Buildings 16, 44, 615 (2002-2022) + USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX (2019-2022) + USACE Fort Worth District - Repair Building B499 Randolph Air Force Base, TX (2019-2022) + Canadian River Wagon Bridge Deck Replacement, TX (2015) ', 'Projects': '  Renovation of five historical buildings to provide functional administrative office space Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX Repair Building B499 Randolph Air Force Base, TX Canadian River Wagon Bridge Deck Replacement, TX ', 'Roles and Responsibilities': '  Developed DQC plans and ensured quality of all deliverables for various projects Reviewed architectural designs, programming, space planning, furniture footprints, interior finish materials, accessories, signage, and built-in case work Performed Quality Assurance reviews of all design deliverables Oversaw onsite design development workshops, functional analysis, and schematics'}
# Processing: page_5.pdf
# Extracted text from page 1 of page_5.pdf...
# {'Here is a summarized version of the resume text': ' ', 'Name': 'Robert Gaylord', 'Education Qualification': 'PE (Civil), BS in Civil Engineering', 'Role': 'Sr. Civil Engineer', 'Licenses': '', 'PE (Civil)': 'FL #51373 (1997)', 'Company': 'SAI-Kenall JV, Orlando, FL ', 'Qualifications': '  35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs ', 'Experience': '  Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management ', 'Projects': '  1. Paint and Sandblast Facility, USCG Miami Station, FL (2021) Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019) Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station 3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021) Sr. Civil Engineer for the design of two new pre-engineered storage facilities 4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023) Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space 5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, PR (2022) Sr. Civil Engineer for the relocation of all utilities associated with the replacement of the Notre Dame Bridge and addition of a pedestrian bridge ', 'Roles and Responsibilities': '  Provided design direction, oversite, and administration services Conducted QC review and peer review of civil design including site work, utilities, landscaping, and drainage Performed design review and construction administration services Coordinated with clients and contractors throughout the project phase'}

# %%
sum_dict
# Out:
# [{'Here is the summarized version of the resume': ' ',
#   'Name': 'Kris D. Prasad',
#   'Role': 'Program/Project Manager ',
#   'Company': 'Kenall-Hana JV, LLC',
#   'Location': 'Meridian, MS',
#   'Education': ' - M.S., Civil Engineering (1992) ',
#   'Licenses': '',
#   '- P.E. (Civil)': 'TX #91952, LA #34186, NM #20737, PR #28316 ',
#   'Qualifications': ' - Over 29 years of professional engineering and management experience - Currently serving as task order manager for USACE Fort Worth and Tulsa Districts - Experience includes over 1,000 projects with a value of over $100M - Member of SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ',
#   'Experience': ' - Program/Project Manager at Kenall-Hana JV, LLC for various federal, state, municipal, and local programs - Task order manager for USACE Fort Worth and Tulsa Districts on civil works and military projects - Managed contracts, coordinated with USACE and subcontractors, and prepared full construction plans ',
#   'Projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, 2002, and 2006',
#   'Construction': '2019',
#   'Cost': '$890K',
#   'Professional Services': '2020, Construction: 2021',
#   'Note': 'I have kept the same format as requested, with clear headings and concise summaries of each section.',
#   'vector': [0.013956050388514996,
#    0.02892104536294937,
#    0.02662540227174759,
#    -0.05028749629855156,
#    -0.024570487439632416,
#    0.01663677766919136,
#    -0.11919740587472916,
#    0.02321973815560341,
#    -0.024614589288830757,
#    -0.03511323779821396,
#    -0.06065008416771889,
#    -0.010676064528524876,
#    0.07107223570346832,
#    -0.034276675432920456,
#    -0.09032182395458221,
#    -0.0027386010624468327,
#    -0.0201705452054739,
#    -0.06415785104036331,
#    -0.012761490419507027,
#    -0.06182364001870155,
#    0.06622244417667389,
#    0.014595468528568745,
#    -0.0029522909317165613,
#    -0.061401382088661194,
#    0.08301739394664764,
#    0.018910327926278114,
#    0.01641196757555008,
#    0.07044849544763565,
#    -0.045800838619470596,
#    -0.0032821071799844503,
#    0.05312178283929825,
#    0.08086192607879639,
#    -0.019100988283753395,
#    0.046522654592990875,
#    0.11958805471658707,
#    0.12069907039403915,
#    -0.05758490785956383,
#    -0.006930675357580185,
#    0.007179351057857275,
#    0.026090743020176888,
#    -0.06860474497079849,
#    0.001705739414319396,
#    0.06506948918104172,
#    0.0009151059202849865,
#    -0.026877719908952713,
#    -0.0024938031565397978,
#    -0.042784154415130615,
#    -0.05893576145172119,
#    -0.05701731517910957,
#    -0.06940950453281403,
#    -0.039559993892908096,
jects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, 2002, and 2006\n\t Location: Fort Sam Houston, TX\n\t Construction: 2022\n\t Cost: $31M\n\t Role: Program/Project Manager\n2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot\n\t Location: Texarkana, TX\n\t Construction: 2022\n\t Cost: $16.5M\n\t Role: Program/Project Manager\n3. USACE Fort Worth District - Repair North Fort Hood Drainage\n\t Location: Fort Hood, TX\n\t Professional Services: 2020, Construction: 2021\n\t Cost: $5.5M\n\t Role: Program/Project Manager\n4. NAVFAC Southeast - Site Preparation for Digital Airport Surveillance Radar (DASR)\n\t Location: Meridian, MS\n\t Construction: 2019\n\t Cost: $890K\n\t Role: Program/Project Manager\n\nNote: I have kept the same format as requested, with clear headings and concise summaries of each section.'},
#  {'Here is a summarized version of the resume': ' ',
#   'Name': 'Kris D. Prasad, PE ',
#   'Education Qualification': 'MS, Civil Engineering (1992) ',
#   'Role': 'Program Manager/Senior Structural Engineer ',
#   'Licenses': ' ',
#   'PE (Civil)': 'TX #91952 (2003), LA #34186, NM #20737, PR# 28316 Other professional registrations not specified ',
#   'Company': 'SAT-Kenall JV, Houston, TX ',
#   'Qualifications': '  Over 29 years of professional engineering and management experience Experience with various federal, state, municipal, and local programs Currently serving as Program Manager for USACE Fort Worth and Tulsa Districts Previously served as task order manager for two NAVFAC Southeast projects Member of organizations such as SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ',
#   'Experience': '  Program Manager/Senior Structural Engineer at SAT-Kenall JV (20 years) Experience with over 1000 projects worth over $100M Managed various civil works and military projects for USACE Fort Worth and Tulsa Districts Performed contract management, coordinated with USACE and subcontractors, and ensured timely submission of deliverables ',
#   'Projects': ' ',
#   '1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615': 'Program Manager/Senior Structural Engineer (2002-2022) Renovated five historical buildings for functional administrative office space',
#   'Cost': '$3.8M',
#   '2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot': 'Program Manager/Senior Structural Engineer (2021-2022) Managed 27 facility projects including major renovations to a warehouse and fire station',
#   '3. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood': 'Program Manager/Senior Structural Engineer (2019-2022) Designed 4 separate 100% plans & specifications packages for each battalion TEMF',
#   '4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base': 'Program Manager/Senior Structural Engineer (2019-2022) Renovated the entire 3rd floor of B499, HQ at Air Force Personnel Center',
#   'vector': [0.03521519899368286,
#    0.013969453051686287,
#    -0.010823342949151993,
#    -0.05941463261842728,
#    -0.037269413471221924,
#    -0.0086709288880229,
#    -0.11779489368200302,
#    0.05853426083922386,
#    -0.033117715269327164,
#    -0.03768520802259445,
#    -0.03726767748594284,
#    -0.010095102712512016,
#    0.05724504590034485,
#    -0.034727372229099274,
#    -0.10244689881801605,
#    -0.02939058095216751,
#    -0.010030681267380714,
#    -0.03107771836221218,
#    0.01688888855278492,
#    -0.03214968740940094,
#   'summary': 'Here is a summarized version of the resume:\n\nName: Kris D. Prasad, PE\n\nEducation Qualification: MS, Civil Engineering (1992)\n\nRole: Program Manager/Senior Structural Engineer\n\nLicenses:\n\n PE (Civil): TX #91952 (2003), LA #34186, NM #20737, PR# 28316\n Other professional registrations not specified\n\nCompany: SAT-Kenall JV, Houston, TX\n\nQualifications:\n\n Over 29 years of professional engineering and management experience\n Experience with various federal, state, municipal, and local programs\n Currently serving as Program Manager for USACE Fort Worth and Tulsa Districts\n Previously served as task order manager for two NAVFAC Southeast projects\n Member of organizations such as SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico\n\nExperience:\n\n Program Manager/Senior Structural Engineer at SAT-Kenall JV (20 years)\n Experience with over 1000 projects worth over $100M\n Managed various civil works and military projects for USACE Fort Worth and Tulsa Districts\n Performed contract management, coordinated with USACE and subcontractors, and ensured timely submission of deliverables\n\nProjects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615: Program Manager/Senior Structural Engineer (2002-2022)\n\t Renovated five historical buildings for functional administrative office space\n\t Cost: $31M\n2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot: Program Manager/Senior Structural Engineer (2021-2022)\n\t Managed 27 facility projects including major renovations to a warehouse and fire station\n\t Cost: $16.5M\n3. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood: Program Manager/Senior Structural Engineer (2019-2022)\n\t Designed 4 separate 100% plans & specifications packages for each battalion TEMF\n\t Cost: $22M\n4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base: Program Manager/Senior Structural Engineer (2019-2022)\n\t Renovated the entire 3rd floor of B499, HQ at Air Force Personnel Center\n\t Cost: $3.8M'},
#  {'Here is the summarized resume for Srujan Chikyala': ' ',
#   'Name': 'Srujan Chikyala',
#   'Role': 'Project Manager',
#   'Education': '',
#   '- Degree': 'MS, Civil Engineering',
#   '- Specialization': '',
#   '- Year': '2008 ',
#   'Licenses': ' ',
#   'PE (Civil)': 'TX #122374 (2015) ',
#   'Company': 'SAT-Kenall JV',
#   'Location': 'Randolph Air Force Base, TX',
#   'Qualifications': '  Provides 13 years of experience leading DB and DBB RFP packages for MILCON and SRM projects at USACE and NAVFAC military facilities and civil works projects for USACE, USDA-NRCS, IBWC, and US Fish & Wildlife Service. Served as a Project Manager on about 75+ engineering projects for federal, public works and public entities that include military facilities, utilities, drainage structures, roadways, bridges, dams, levees, facilities, and other flood control structures for various federal clients. ',
#   'Experience': '  Project Manager',
#   'Years of Experience': '13 ',
#   'Projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, and others',
#   'Year Completed': '2019-2022',
#   'Brief Description': 'Renovated the entire 3rd floor of B499, HQ, at Air Force Personnel Center. Cost: $3.8M. ',
#   'Note': "The provided information is based on the text and might not be a comprehensive summary of Srujan Chikyala's resume or experience.",
#   'vector': [0.010223339311778545,
#    -0.001677894964814186,
#    -0.040959592908620834,
#    -0.055469632148742676,
#    -0.0006865148316137493,
#    0.04556719958782196,
#    -0.10383673012256622,
#    0.04398788511753082,
#    -0.03875420615077019,
#    0.11229532957077026,
#    -0.0023882323876023293,
#    -0.018323268741369247,
#    -0.02527286857366562,
#    -0.04319795221090317,
#    -0.03669125586748123,
#    -0.04306228086352348,
#    -0.020575640723109245,
#    0.030446162447333336],
#   'summary': "Here is the summarized resume for Srujan Chikyala:\n\nName: Srujan Chikyala\nRole: Project Manager\n\nEducation:\n- Degree: MS, Civil Engineering\n- Specialization: \n- Year: 2008\n\nLicenses:\n\n PE (Civil): TX #122374 (2015)\n\nCompany: SAT-Kenall JV\nLocation: Houston, TX\n\nQualifications:\n\n Provides 13 years of experience leading DB and DBB RFP packages for MILCON and SRM projects at USACE and NAVFAC military facilities and civil works projects for USACE, USDA-NRCS, IBWC, and US Fish & Wildlife Service.\n Served as a Project Manager on about 75+ engineering projects for federal, public works and public entities that include military facilities, utilities, drainage structures, roadways, bridges, dams, levees, facilities, and other flood control structures for various federal clients.\n\nExperience:\n\n Project Manager\n Years of Experience: 13\n\nProjects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, and others\n\t Location: Fort Sam Houston, TX\n\t Year Completed: 2006-2022\n\t Role: Project Manager\n\t Brief Description: Renovated five historical buildings (total 100,400 SF renovation area) to provide functional administrative office space with a 25-year usable life. Cost: $31M.\n2. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX\n\t Location: Fort Hood, TX\n\t Year Completed: 2019-2022\n\t Role: Project Manager\n\t Brief Description: Brought four TEMFs to meet current design standard to enhance functionality to meet mission requirements and achieve a longer useful life. Cost: $22M.\n3. USACE Fort Worth District - AE Services for Design-Build Repair Building 6426, Hangar 3, for 11th Bomb Squadron, Barksdale AFB, LA\n\t Location: Barksdale AFB, LA\n\t Year Completed: 2018-2020\n\t Role: Project Manager\n\t Brief Description: Renovated a hangar that resulted in a usable facility conforming to UFC & USAF design criteria. The facility was circa 1935 masonry, concrete, and steel aircraft hangar that had undergone previous renovations. Cost: $6.6M.\n4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base, TX\n\t Location: Randolph Air Force Base, TX\n\t Year Completed: 2019-2022\n\t Role: Project Manager\n\t Brief Description: Renovated the entire 3rd floor of B499, HQ, at Air Force Personnel Center. Cost: $3.8M.\n\nNote: The provided information is based on the text and might not be a comprehensive summary of Srujan Chikyala's resume or experience."},
#  {'Here is the summarized resume in the required format': ' ',
#   'Name': 'Brett Witte, PE ',
#   'Education Qualification': 'BS, Civil Engineering (2005) ',
#   'Role': 'Project Manager / Civil Engineer ',
#   'Licenses': ' ',
#   'PE (Civil)': 'FL #70720 (2010)',
#   'Current Professional Registration (State and Discipline)': 'Not specified ',
#   'Company': 'SAI-Kenall JV, Orlando, FL ',
#   'Qualifications': '  Over 18 years of experience in conducting engineering design, analysis, calculations, and developing technical specifications for civil infrastructure design projects Skilled at H&H modeling using numerous programs, civil infrastructure design, construction plans production using MicroStation and AutoCAD, quantity take-offs, cost estimates, construction phase support and as-built certifications ',
#    -0.057156674563884735,
#    -0.04806070029735565,
#    0.0980239287018776,
#    0.061293426901102066,
#    0.001976482104510069,
#    -0.11257829517126083,
#    0.11333733052015305,
#    0.02760637365281582,
#    -0.05931231379508972,
#    0.035594839602708817,
#    0.023298140615224838,
#    0.08703025430440903,
#    0.06162729114294052,
#    -0.027147185057401657,
#    0.01468358002603054,
#    -0.030442975461483,
#    0.0014410251751542091,
#    -0.06439967453479767,
#    0.02693026140332222,
# ...
#  {'Here is a summarized version of the resume text': ' ',
#   'Name': 'Robert Gaylord',
#   'Education Qualification': 'PE (Civil), BS in Civil Engineering',
#   'Role': 'Sr. Civil Engineer',
#   'Licenses': '',
#   'PE (Civil)': 'FL #51373 (1997)',
#   'Company': 'SAI-Kenall JV, Orlando, FL ',
#   'Qualifications': '  35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs ',
#   'Experience': '  Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management ',
#   'Projects': '  1. Paint and Sandblast Facility, USCG Miami Station, FL (2021) Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019) Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station 3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021) Sr. Civil Engineer for the design of two new pre-engineered storage facilities 4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023) Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space 5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, PR (2022) Sr. Civil Engineer for the relocation of all utilities associated with the replacement of the Notre Dame Bridge and addition of a pedestrian bridge ',
#   'Roles and Responsibilities': '  Provided design direction, oversite, and administration services Conducted QC review and peer review of civil design including site work, utilities, landscaping, and drainage Performed design review and construction administration services Coordinated with clients and contractors throughout the project phase',
#   'vector': [-0.026163751259446144,
#    0.07059447467327118,
#    0.00884155835956335,
#    -0.05212462693452835,
#    0.042008668184280396,
#    -0.028380870819091797,
#    -0.0918283686041832,
#    0.05196250230073929,
#    -0.0027737761847674847,
#    -0.03064875863492489,
#    -0.06269236654043198,
#    -0.005873632151633501,
#    0.06493420153856277,
#    -0.013628187589347363,
#    -0.06612000614404678,
#    -0.014881078153848648,
#    -0.05954929068684578,
#    -0.03780308738350868,
#    -0.00961887277662754,
#    -0.03749833628535271,
#    0.00327176577411592,
#    0.012010624632239342,
#    0.0367593951523304,
#    -0.054503437131643295,
#    0.05491971597075462,
#    0.006021707784384489,
#    0.031545378267765045,
#    0.09466129541397095,
#    -0.09160879254341125,
#    -0.02619684487581253,
#    0.06964089721441269,
#    0.09276124089956284,
#   'summary': 'Here is a summarized version of the resume text:\n\nName: Robert Gaylord\nEducation Qualification: PE (Civil), BS in Civil Engineering\nRole: Sr. Civil Engineer\nLicenses:\n PE (Civil): FL #51373 (1997)\nCompany: SAI-Kenall JV, Orlando, FL\n\nQualifications:\n\n 35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects\n Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs\n\nExperience:\n\n Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico\n Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management\n\nProjects:\n\n1. Paint and Sandblast Facility, USCG Miami Station, FL (2021)\n\t Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building\n2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019)\n\t Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station\n3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021)\n\t Sr. Civil Engineer for the design of two new pre-engineered storage facilities\n4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023)\n\t Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space\n5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, PR (2022)\n\t Sr. Civil Engineer for the relocation of all utilities associated with the replacement of the Notre Dame Bridge and addition of a pedestrian bridge\n\nRoles and Responsibilities:\n\n Provided design direction, oversite, and administration services\n Conducted QC review and peer review of civil design including site work, utilities, landscaping, and drainage\n Performed design review and construction administration services\n Coordinated with clients and contractors throughout the project phase'}]

# %%
def Create_collection4resume():
    from weaviate.classes.config import ReferenceProperty
    client = weaviate.connect_to_local(port=8082)
    # Delete a collection
    employee = "testing_employee"
    companies = "testing_Companies"

    if client.collections.exists(name=companies):
        client.collections.delete(name=companies)
        print("Existing", companies ,"collection deleted.")

    client.collections.create(
        name=companies,  # Name of the data collection for collecting company names
        properties=[
            Property(name="company_name", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="emp_names", data_type = DataType.TEXT,index_searchable=True,index_filterable=True)
        ])
    print("Collection",companies," created successfully.")

    if client.collections.exists(name=employee):
        client.collections.delete(name=employee)
        print("Existing",employee,"collection deleted.")


    client.collections.create(
        name=employee,  # Name of the data collection for collecting employee details
        properties=[
            Property(name="Name", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="role", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="company", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="qualification", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="experience", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="projects", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="roles_responsibilities", data_type=DataType.TEXT,index_searchable=True,index_filterable=True),
            Property(name="summary", data_type = DataType.TEXT,index_searchable=True,index_filterable=True)
        ],
        references=[
            ReferenceProperty(
                name="company_name",
                target_collection = companies
            )
        ]

    )
    print("Collection",employee," created successfully.")

    #making connection from "companies" to "employee"
    company = client.collections.get(companies)
    company.config.add_reference(
        ReferenceProperty(
            name="Name",
            target_collection=employee
        )
    )






    client.close()

# %%
def load_ResumeInCollection():
    
    client = weaviate.connect_to_local(port = 8082)

    # Get the collections
    emp = client.collections.get("testing_employee")
    comp = client.collections.get("testing_Companies")

    # Batch process for the 'employee' collection
    employee_names = []
    employee_uuids ={}
    dup_emp = {}
    company_names = {}
    with emp.batch.dynamic() as batch:

        for d in sum_dict:
            if d["Name"] in employee_names:
                dup_emp.setdefault(d["Name"],[])
                dup_emp[d["Name"]].append(d["summary"])

            else:
                employee_uuid = batch.add_object({

                    "Name": d["Name"],
                    "role": d["Role"],
                    "company": d["Company"],
                    "license": next(
                        (d.get(key) for key in ["Licenses/Certifications", "Licenses", "PE (Civil)"] if key in d),
                        "Not provided"  # Default value if none of the keys exist
                    ),
                    "qualification": next(
                        (d.get(key) for key in ["Qualifications", "Summary of Qualifications"] if key in d),
                        "Not provided"  # Default value
                    ),
                    "experience": d["Experience"],
                    "projects": d.get("Projects", "not found"),
                    "summary": d["summary"],
                }, vector=d["vector"])

                employee_names.append(d["Name"])

                employee_uuids[d["Name"]] = employee_uuid  # Map Name to UUID for later reference

                company_names.setdefault(d["Company"],[])
                company_names[d["Company"]].append(d["Name"])
                




    for i in dup_emp:
        for item in emp.iterator():
            if (i == item.properties["name"]):
                temp = item.properties["summary"] + " "+ dup_emp[i][0]
                print("updating ", i)
                
                emp.data.update(
                    uuid=employee_uuids[i],
                    properties={
                        "summary": temp,
                        
                    }
                )

    with comp.batch.dynamic() as batch:

        for d in company_names:
            temp = ""
            for i in company_names[d]:
                temp= i +" | "+ temp
            batch.add_object({
                "company_name" : d,
                "emp_names" : temp
            })





    client.close()

# %% [markdown]
# Create collection and load resumes here

# %% [markdown]
# load resumes here

# %%
client = weaviate.connect_to_local(port="8082")
obj = client.collections.get("testing_Companies")
for i in obj.iterator():
    print(i.properties)
client.close()
# Out:
# {'emp_names': 'Robert Morris, AIA, RID DQC Manager | ', 'company_name': 'SAI-Kenall JV'}
# {'emp_names': 'Robert Gaylord | Brett Witte, PE  | ', 'company_name': 'SAI-Kenall JV, Orlando, FL '}
# {'emp_names': 'Kris D. Prasad | ', 'company_name': 'Kenall-Hana JV, LLC'}
# {'emp_names': 'Kris D. Prasad, PE  | ', 'company_name': 'SAT-Kenall JV, Houston, TX '}
# {'emp_names': 'Srujan Chikyala | ', 'company_name': 'SAT-Kenall JV'}

# %%
client = weaviate.connect_to_local(port="8082")
emp = client.collections.get("testing_employee")
for item in emp.iterator():
    print(item.properties)
client.close()
# Out:
# {'name': 'Brett Witte, PE ', 'company': 'SAI-Kenall JV, Orlando, FL ', 'qualification': '  Over 18 years of experience in conducting engineering design, analysis, calculations, and developing technical specifications for civil infrastructure design projects Skilled at H&H modeling using numerous programs, civil infrastructure design, construction plans production using MicroStation and AutoCAD, quantity take-offs, cost estimates, construction phase support and as-built certifications ', 'summary': 'Here is the summarized resume in the required format:\n\nName: Brett Witte, PE\n\nEducation Qualification: BS, Civil Engineering (2005)\n\nRole: Project Manager / Civil Engineer\n\nLicenses:\n\n PE (Civil): FL #70720 (2010)\n Current Professional Registration (State and Discipline): Not specified\n\nCompany: SAI-Kenall JV, Orlando, FL\n\nQualifications:\n\n Over 18 years of experience in conducting engineering design, analysis, calculations, and developing technical specifications for civil infrastructure design projects\n Skilled at H&H modeling using numerous programs, civil infrastructure design, construction plans production using MicroStation and AutoCAD, quantity take-offs, cost estimates, construction phase support and as-built certifications\n\nExperience:\n\n1. Project Manager / Civil Engineer, Paint and Sandblast Facility, USCG Miami Station, FL (2021)\n\t Coordinated between disciplines\n\t Led civil design through 65%, 95%, and 100% design documents\n\t Attended design review meetings and prepared materials\n2. Project Manager / Civil Engineer, Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019)\n\t Coordinated between disciplines\n\t Designed engineer for preparation of construction plans\n3. Project Manager / Civil Engineer, CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021)\n\t Coordinated between disciplines\n\t Designed engineer for preparation of construction plans\n4. Civil Engineer, USACE Fort Worth District - A-E Services for Red River Army Depot — Install Security Fences and Repair Buildings, Texarkana, TX (2019-2020)\n\t Performed QC of 65%, 95%, and 100% design documents\n\nProjects:\n\n1. Paint and Sandblast Facility, USCG Miami Station, FL\n2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL\n3. CES and FES Warehouses, MacDill AFB, Tampa, FL\n4. Security Fences and Repair Buildings, Texarkana, TX\n\nRoles and Responsibilities:\n\n Conducted engineering design, analysis, calculations, and developed technical specifications for civil infrastructure design projects\n Coordinated between disciplines\n Led civil design through 65%, 95%, and 100% design documents\n Attended design review meetings and prepared materials\n Performed QC of 65%, 95%, and 100% design documents', 'roles_responsibilities': None, 'role': 'Project Manager / Civil Engineer ', 'experience': '  1. Project Manager / Civil Engineer, Paint and Sandblast Facility, USCG Miami Station, FL (2021) Coordinated between disciplines Led civil design through 65%, 95%, and 100% design documents Attended design review meetings and prepared materials 2. Project Manager / Civil Engineer, Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019) Coordinated between disciplines Designed engineer for preparation of construction plans 3. Project Manager / Civil Engineer, CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021) Coordinated between disciplines Designed engineer for preparation of construction plans 4. Civil Engineer, USACE Fort Worth District - A-E Services for Red River Army Depot — Install Security Fences and Repair Buildings, Texarkana, TX (2019-2020) Performed QC of 65%, 95%, and 100% design documents ', 'license': ' ', 'projects': '  1. Paint and Sandblast Facility, USCG Miami Station, FL 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL 3. CES and FES Warehouses, MacDill AFB, Tampa, FL 4. Security Fences and Repair Buildings, Texarkana, TX '}
# {'name': 'Robert Gaylord', 'company': 'SAI-Kenall JV, Orlando, FL ', 'qualification': '  35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs ', 'roles_responsibilities': None, 'summary': 'Here is a summarized version of the resume text:\n\nName: Robert Gaylord\nEducation Qualification: PE (Civil), BS in Civil Engineering\nRole: Sr. Civil Engineer\nLicenses:\n PE (Civil): FL #51373 (1997)\nCompany: SAI-Kenall JV, Orlando, FL\n\nQualifications:\n\n 35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects\n Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs\n\nExperience:\n\n Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico\n Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management\n\nProjects:\n\n1. Paint and Sandblast Facility, USCG Miami Station, FL (2021)\n\t Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building\n2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019)\n\t Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station\n3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021)\n\t Sr. Civil Engineer for the design of two new pre-engineered storage facilities\n4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023)\n\t Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space\n5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, PR (2022)\n\t Sr. Civil Engineer for the relocation of all utilities associated with the replacement of the Notre Dame Bridge and addition of a pedestrian bridge\n\nRoles and Responsibilities:\n\n Provided design direction, oversite, and administration services\n Conducted QC review and peer review of civil design including site work, utilities, landscaping, and drainage\n Performed design review and construction administration services\n Coordinated with clients and contractors throughout the project phase', 'role': 'Sr. Civil Engineer', 'experience': '  Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management ', 'license': '', 'projects': '  1. Paint and Sandblast Facility, USCG Miami Station, FL (2021) Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019) Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station 3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021) Sr. Civil Engineer for the design of two new pre-engineered storage facilities 4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023) Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space 5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, ...
# {'projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, and others', 'company': 'SAT-Kenall JV', 'qualification': '  Provides 13 years of experience leading DB and DBB RFP packages for MILCON and SRM projects at USACE and NAVFAC military facilities and civil works projects for USACE, USDA-NRCS, IBWC, and US Fish & Wildlife Service. Served as a Project Manager on about 75+ engineering projects for federal, public works and public entities that include military facilities, utilities, drainage structures, roadways, bridges, dams, levees, facilities, and other flood control structures for various federal clients. ', 'summary': "Here is the summarized resume for Srujan Chikyala:\n\nName: Srujan Chikyala\nRole: Project Manager\n\nEducation:\n- Degree: MS, Civil Engineering\n- Specialization: \n- Year: 2008\n\nLicenses:\n\n PE (Civil): TX #122374 (2015)\n\nCompany: SAT-Kenall JV\nLocation: Houston, TX\n\nQualifications:\n\n Provides 13 years of experience leading DB and DBB RFP packages for MILCON and SRM projects at USACE and NAVFAC military facilities and civil works projects for USACE, USDA-NRCS, IBWC, and US Fish & Wildlife Service.\n Served as a Project Manager on about 75+ engineering projects for federal, public works and public entities that include military facilities, utilities, drainage structures, roadways, bridges, dams, levees, facilities, and other flood control structures for various federal clients.\n\nExperience:\n\n Project Manager\n Years of Experience: 13\n\nProjects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, and others\n\t Location: Fort Sam Houston, TX\n\t Year Completed: 2006-2022\n\t Role: Project Manager\n\t Brief Description: Renovated five historical buildings (total 100,400 SF renovation area) to provide functional administrative office space with a 25-year usable life. Cost: $31M.\n2. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX\n\t Location: Fort Hood, TX\n\t Year Completed: 2019-2022\n\t Role: Project Manager\n\t Brief Description: Brought four TEMFs to meet current design standard to enhance functionality to meet mission requirements and achieve a longer useful life. Cost: $22M.\n3. USACE Fort Worth District - AE Services for Design-Build Repair Building 6426, Hangar 3, for 11th Bomb Squadron, Barksdale AFB, LA\n\t Location: Barksdale AFB, LA\n\t Year Completed: 2018-2020\n\t Role: Project Manager\n\t Brief Description: Renovated a hangar that resulted in a usable facility conforming to UFC & USAF design criteria. The facility was circa 1935 masonry, concrete, and steel aircraft hangar that had undergone previous renovations. Cost: $6.6M.\n4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base, TX\n\t Location: Randolph Air Force Base, TX\n\t Year Completed: 2019-2022\n\t Role: Project Manager\n\t Brief Description: Renovated the entire 3rd floor of B499, HQ, at Air Force Personnel Center. Cost: $3.8M.\n\nNote: The provided information is based on the text and might not be a comprehensive summary of Srujan Chikyala's resume or experience.", 'roles_responsibilities': None, 'role': 'Project Manager', 'experience': '  Project Manager', 'license': ' ', 'name': 'Srujan Chikyala'}
# {'name': 'Kris D. Prasad, PE ', 'company': 'SAT-Kenall JV, Houston, TX ', 'qualification': '  Over 29 years of professional engineering and management experience Experience with various federal, state, municipal, and local programs Currently serving as Program Manager for USACE Fort Worth and Tulsa Districts Previously served as task order manager for two NAVFAC Southeast projects Member of organizations such as SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ', 'roles_responsibilities': None, 'summary': 'Here is a summarized version of the resume:\n\nName: Kris D. Prasad, PE\n\nEducation Qualification: MS, Civil Engineering (1992)\n\nRole: Program Manager/Senior Structural Engineer\n\nLicenses:\n\n PE (Civil): TX #91952 (2003), LA #34186, NM #20737, PR# 28316\n Other professional registrations not specified\n\nCompany: SAT-Kenall JV, Houston, TX\n\nQualifications:\n\n Over 29 years of professional engineering and management experience\n Experience with various federal, state, municipal, and local programs\n Currently serving as Program Manager for USACE Fort Worth and Tulsa Districts\n Previously served as task order manager for two NAVFAC Southeast projects\n Member of organizations such as SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico\n\nExperience:\n\n Program Manager/Senior Structural Engineer at SAT-Kenall JV (20 years)\n Experience with over 1000 projects worth over $100M\n Managed various civil works and military projects for USACE Fort Worth and Tulsa Districts\n Performed contract management, coordinated with USACE and subcontractors, and ensured timely submission of deliverables\n\nProjects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615: Program Manager/Senior Structural Engineer (2002-2022)\n\t Renovated five historical buildings for functional administrative office space\n\t Cost: $31M\n2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot: Program Manager/Senior Structural Engineer (2021-2022)\n\t Managed 27 facility projects including major renovations to a warehouse and fire station\n\t Cost: $16.5M\n3. USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood: Program Manager/Senior Structural Engineer (2019-2022)\n\t Designed 4 separate 100% plans & specifications packages for each battalion TEMF\n\t Cost: $22M\n4. USACE Fort Worth District - Repair Building B499 Randolph Air Force Base: Program Manager/Senior Structural Engineer (2019-2022)\n\t Renovated the entire 3rd floor of B499, HQ at Air Force Personnel Center\n\t Cost: $3.8M', 'role': 'Program Manager/Senior Structural Engineer ', 'experience': '  Program Manager/Senior Structural Engineer at SAT-Kenall JV (20 years) Experience with over 1000 projects worth over $100M Managed various civil works and military projects for USACE Fort Worth and Tulsa Districts Performed contract management, coordinated with USACE and subcontractors, and ensured timely submission of deliverables ', 'license': ' ', 'projects': ' '}
# {'name': 'Kris D. Prasad', 'company': 'Kenall-Hana JV, LLC', 'qualification': ' - Over 29 years of professional engineering and management experience - Currently serving as task order manager for USACE Fort Worth and Tulsa Districts - Experience includes over 1,000 projects with a value of over $100M - Member of SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico ', 'roles_responsibilities': None, 'summary': 'Here is the summarized version of the resume:\n\nName: Kris D. Prasad\nRole: Program/Project Manager\nCompany: Kenall-Hana JV, LLC\nLocation: Houston, TX\n\nEducation:\n- M.S., Civil Engineering (1992)\n\nLicenses:\n- P.E. (Civil): TX #91952, LA #34186, NM #20737, PR #28316\n\nQualifications:\n- Over 29 years of professional engineering and management experience\n- Currently serving as task order manager for USACE Fort Worth and Tulsa Districts\n- Experience includes over 1,000 projects with a value of over $100M\n- Member of SAME, ASCE, ACEC, College of Engineers and Surveyors of Puerto Rico\n\nExperience:\n- Program/Project Manager at Kenall-Hana JV, LLC for various federal, state, municipal, and local programs\n- Task order manager for USACE Fort Worth and Tulsa Districts on civil works and military projects\n- Managed contracts, coordinated with USACE and subcontractors, and prepared full construction plans\n\nProjects:\n\n1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, 2002, and 2006\n\t Location: Fort Sam Houston, TX\n\t Construction: 2022\n\t Cost: $31M\n\t Role: Program/Project Manager\n2. USACE Fort Worth District - Repair Fire Protection, Install Security Fences and Repairs of Buildings at Red River Army Depot\n\t Location: Texarkana, TX\n\t Construction: 2022\n\t Cost: $16.5M\n\t Role: Program/Project Manager\n3. USACE Fort Worth District - Repair North Fort Hood Drainage\n\t Location: Fort Hood, TX\n\t Professional Services: 2020, Construction: 2021\n\t Cost: $5.5M\n\t Role: Program/Project Manager\n4. NAVFAC Southeast - Site Preparation for Digital Airport Surveillance Radar (DASR)\n\t Location: Meridian, MS\n\t Construction: 2019\n\t Cost: $890K\n\t Role: Program/Project Manager\n\nNote: I have kept the same format as requested, with clear headings and concise summaries of each section.', 'role': 'Program/Project Manager ', 'experience': ' - Program/Project Manager at Kenall-Hana JV, LLC for various federal, state, municipal, and local programs - Task order manager for USACE Fort Worth and Tulsa Districts on civil works and military projects - Managed contracts, coordinated with USACE and subcontractors, and prepared full construction plans ', 'license': '', 'projects': '  1. USACE Fort Worth District - Renovation of Buildings 16, 44, 615, 2002, and 2006'}
# {'projects': '  Renovation of five historical buildings to provide functional administrative office space Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX Repair Building B499 Randolph Air Force Base, TX Canadian River Wagon Bridge Deck Replacement, TX ', 'company': 'SAI-Kenall JV', 'qualification': '  Experienced with a wide range of building projects and systems Skilled in master planning, programming, and design of architectural projects Performed over 100 detailed Facility Condition Assessments (FCAs) over the past fifteen years ', 'summary': 'Here is the summarized resume for Robert Morris:\n\nName: Robert Morris, AIA, RID DQC Manager\nEducation Qualification: BA, Architectural Design, 1981\n\nRole: DQC Manager, Architect, and Innovator\n\nLicenses:\n Registered Architect: TX #12112 (1987)\n Registered Interior Designer: TX # 1985 (1993)\n\nCompany: SAI-Kenall JV\nLocation: Houston, TX\n\nQualifications:\n\n Experienced with a wide range of building projects and systems\n Skilled in master planning, programming, and design of architectural projects\n Performed over 100 detailed Facility Condition Assessments (FCAs) over the past fifteen years\n\nExperience:\n\n DQC Manager for various projects including:\n\t+ USACE Fort Worth District - Renovation of Buildings 16, 44, 615 (2002-2022)\n\t+ USACE Fort Worth District - Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX (2019-2022)\n\t+ USACE Fort Worth District - Repair Building B499 Randolph Air Force Base, TX (2019-2022)\n\t+ Canadian River Wagon Bridge Deck Replacement, TX (2015)\n\nProjects:\n\n Renovation of five historical buildings to provide functional administrative office space\n Design of Tactical Equipment Maintenance Facility (TEMF) Renovations at Fort Hood, TX\n Repair Building B499 Randolph Air Force Base, TX\n Canadian River Wagon Bridge Deck Replacement, TX\n\nRoles and Responsibilities:\n\n Developed DQC plans and ensured quality of all deliverables for various projects\n Reviewed architectural designs, programming, space planning, furniture footprints, interior finish materials, accessories, signage, and built-in case work\n Performed Quality Assurance reviews of all design deliverables\n Oversaw onsite design development workshops, functional analysis, and schematics', 'roles_responsibilities': None, 'role': 'DQC Manager, Architect, and Innovator ', 'experience': ' ', 'license': '', 'name': 'Robert Morris, AIA, RID DQC Manager'}

# %% [markdown]
# clear till here(data loaded in Db)

# %%
client = weaviate.connect_to_local(port="8082")
emp = client.collections.get("testing_employee")
query_vector = compute_embeddings("""the following engineers may be required for this project:

1. Civil engineers with experience in construction or infrastructure development.
2. Structural engineers to design and ensure structural integrity of buildings, bridges, or other structures.
3. Environmental engineers to assess and mitigate environmental impacts.
4. Geotechnical engineers to evaluate soil and rock conditions.""")

response = emp.query.near_vector(
    near_vector=query_vector,
    limit=4,
    return_metadata=wvc.query.MetadataQuery(certainty=True)
)

print(response.objects[0].properties["summary"])
client.close()
# Out:
# Here is a summarized version of the resume text:
#
# Name: Robert Gaylord
# Education Qualification: PE (Civil), BS in Civil Engineering
# Role: Sr. Civil Engineer
# Licenses:
#  PE (Civil): FL #51373 (1997)
# Company: SAI-Kenall JV, Orlando, FL
#
# Qualifications:
#
#  35 years of experience conducting engineering design, analysis, and developing technical specifications for civil infrastructure design projects
#  Expertise in complex H&H modeling and flood control design as well as administering construction & implementation of project designs
#
# Experience:
#
#  Sr. Civil Engineer for various USACE Districts (including Jacksonville), US Air Force, and other federal agencies including military installations and federal facilities in Florida and Puerto Rico
#  Led and supported projects with expertise in civil infrastructure design including site design, utilities, roads, parking, airfields, parks, pump stations, and stormwater management
#
# Projects:
#
# 1. Paint and Sandblast Facility, USCG Miami Station, FL (2021)
# 	 Sr. Civil Engineer for the construction of a new paint and sandblast facility to replace the existing damaged and undersized building
# 2. Relocate AGE Refueling Station, MacDill AFB, Tampa, FL (2019)
# 	 Sr. Civil Engineer for the relocation of an Aerospace Ground Equipment refueling station
# 3. CES and FES Warehouses, MacDill AFB, Tampa, FL (2020-2021)
# 	 Sr. Civil Engineer for the design of two new pre-engineered storage facilities
# 4. USACE Fort Worth District - A-E Services for Renovation of Buildings 16, 44, 615, 2002 and 2006, JBSA, Fort Sam Houston, TX (2022-2023)
# 	 Sr. Civil Engineer for the full renovation of historical buildings to provide functional administrative office space
# 5. Rio Puerto Nuevo Notre Dame Bridge Replacement (CNTSA), San Juan, PR (2022)
# 	 Sr. Civil Engineer for the relocation of all utilities associated with the replacement of the Notre Dame Bridge and addition of a pedestrian bridge
#
# Roles and Responsibilities:
#
#  Provided design direction, oversite, and administration services
#  Conducted QC review and peer review of civil design including site work, utilities, landscaping, and drainage
#  Performed design review and construction administration services
#  Coordinated with clients and contractors throughout the project phase

# %%
#step-1 run only once, that too for the very first time
#creates two collections 1.employee, 2.companies 
Create_collection4resume()
#loads data in both employee and companies collections
load_ResumeInCollection()
# Out:
# Collection testing_Companies  created successfully.
# Collection testing_employee  created successfully.

# %%
client = weaviate.connect_to_local(port="8082")

questions = client.collections.get("testing_employee")
q = """the following engineers may be required for this project:

1. Civil engineers with experience in construction or infrastructure development.
2. Structural engineers to design and ensure structural integrity of buildings, bridges, or other structures.
3. Environmental engineers to assess and mitigate environmental impacts.
4. Geotechnical engineers to evaluate soil and rock conditions."""

response = questions.query.near_text(
    query=q,
    limit=4
)
t=""
for obj in response.objects:
    t += obj.properties["summary"]
    print(obj.properties["summary"])

client.close()  # Free up resources
# Out:
# ---------------------------------------------------------------------------
# AioRpcError                               Traceback (most recent call last)
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\collections\grpc\query.py:805, in _QueryGRPC.__call(self, request)
#     804 assert self._connection.grpc_stub is not None
# --> 805 res = await _Retry(4).with_exponential_backoff(
#     806     0,
#     807     f"Searching in collection {request.collection}",
#     808     self._connection.grpc_stub.Search,
#     809     request,
#     810     metadata=self._connection.grpc_headers(),
#     811     timeout=self._connection.timeout_config.query,
#     812 )
#     813 return cast(search_get_pb2.SearchReply, res)
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\collections\grpc\retry.py:31, in _Retry.with_exponential_backoff(self, count, error, f, *args, **kwargs)
#      30 if e.code() != StatusCode.UNAVAILABLE:
# ---> 31     raise e
#      32 logger.info(
#      33     f"{error} received exception: {e}. Retrying with exponential backoff in {2**count} seconds"
#      34 )
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\collections\grpc\retry.py:28, in _Retry.with_exponential_backoff(self, count, error, f, *args, **kwargs)
#      27 try:
# ---> 28     return await f(*args, **kwargs)
#      29 except AioRpcError as e:
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\grpc\aio\_call.py:327, in _UnaryResponseMixin.__await__(self)
#     326     else:
# --> 327         raise _create_rpc_error(
#     328             self._cython_call._initial_metadata,
#     329             self._cython_call._status,
#     330         )
#     331 else:
#
# AioRpcError: <AioRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "explorer: get class: vectorize params: could not vectorize input for collection Testing_employee with search-type nearText. Make sure a vectorizer module is configured for this collection"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"explorer: get class: vectorize params: could not vectorize input for collection Testing_employee with search-type nearText. Make sure a vectorizer module is configured for this collection", grpc_status:2, created_time:"2025-01-03T18:15:30.7229335+00:00"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# WeaviateQueryError                        Traceback (most recent call last)
# Cell In[29], line 11
#       3 questions = client.collections.get("testing_employee")
#       4 q = """the following engineers may be required for this project:
#       5
#       6 1. Civil engineers with experience in construction or infrastructure development.
#       7 2. Structural engineers to design and ensure structural integrity of buildings, bridges, or other structures.
#       8 3. Environmental engineers to assess and mitigate environmental impacts.
#       9 4. Geotechnical engineers to evaluate soil and rock conditions."""
# ---> 11 response = questions.query.near_text(
#      12     query=q,
#      13     limit=4
#      14 )
#      15 t=""
#      16 for obj in response.objects:
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\syncify.py:23, in convert.<locals>.sync_method(self, __new_name, *args, **kwargs)
#      20 @wraps(method)  # type: ignore
#      21 def sync_method(self, *args, __new_name=new_name, **kwargs):
#      22     async_func = getattr(cls, __new_name)
# ---> 23     return _EventLoopSingleton.get_instance().run_until_complete(
#      24         async_func, self, *args, **kwargs
#      25     )
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\event_loop.py:42, in _EventLoop.run_until_complete(self, f, *args, **kwargs)
#      40     raise WeaviateClosedClientError()
#      41 fut = asyncio.run_coroutine_threadsafe(f(*args, **kwargs), self.loop)
# ---> 42 return fut.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\collections\queries\near_text\query.py:97, in _NearTextQueryAsync.near_text(self, query, certainty, distance, move_to, move_away, limit, offset, auto_limit, filters, group_by, rerank, target_vector, include_vector, return_metadata, return_properties, return_references)
#      27 async def near_text(
#      28     self,
#      29     query: Union[List[str], str],
#    (...)
#      45     return_references: Optional[ReturnReferences[TReferences]] = None,
#      46 ) -> QuerySearchReturnType[Properties, References, TProperties, TReferences]:
#      47     """Search for objects in this collection by text using text-capable vectorization module and vector-based similarity search.
#      48
#      49     See the [docs](https://weaviate.io/developers/weaviate/api/graphql/search-operators#neartext) for a more detailed explanation.
#    (...)
#      95             If the request to the Weaviate server fails.
#      96     """
# ---> 97     res = await self._query.near_text(
#      98         near_text=query,
#      99         certainty=certainty,
#     100         distance=distance,
#     101         move_to=move_to,
#     102         move_away=move_away,
#     103         limit=limit,
#     104         offset=offset,
#     105         autocut=auto_limit,
#     106         filters=filters,
#     107         target_vector=target_vector,
#     108         group_by=_GroupBy.from_input(group_by),
#     109         rerank=rerank,
#     110         return_metadata=self._parse_return_metadata(return_metadata, include_vector),
#     111         return_properties=self._parse_return_properties(return_properties),
#     112         return_references=self._parse_return_references(return_references),
#     113     )
#     114     return self._result_to_query_or_groupby_return(
#     115         res,
#     116         _QueryOptions.from_input(
#    (...)
#     126         return_references,
#     127     )
#
# File c:\Users\AbhinavKasubojula\OneDrive - Kenall Inc\Desktop\code\.venv\Lib\site-packages\weaviate\collections\grpc\query.py:817, in _QueryGRPC.__call(self, request)
#     815     if e.code().name == PERMISSION_DENIED:
#     816         raise InsufficientPermissionsError(e)
# --> 817     raise WeaviateQueryError(str(e), "GRPC search")  # pyright: ignore
#     818 except WeaviateRetryError as e:
#     819     raise WeaviateQueryError(str(e), "GRPC search")
#
# WeaviateQueryError: Query call with protocol GRPC search failed with message <AioRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "explorer: get class: vectorize params: could not vectorize input for collection Testing_employee with search-type nearText. Make sure a vectorizer module is configured for this collection"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"explorer: get class: vectorize params: could not vectorize input for collection Testing_employee with search-type nearText. Make sure a vectorizer module is configured for this collection", grpc_status:2, created_time:"2025-01-03T18:15:30.7229335+00:00"}"
# >.

# %%
prompt_template = f"""Using this data: {t}. Respond to this prompt: the following engineers may be required for this project:

1. Civil engineers with experience in construction or infrastructure development.
2. Structural engineers to design and ensure structural integrity of buildings, bridges, or other structures.
3. Environmental engineers to assess and mitigate environmental impacts.
4. Geotechnical engineers to evaluate soil and rock conditions.
your task is to select 3 candidates from the given data/resumes of employee. give reason for the selection
"""

# %%
# Generate a response combining the prompt and data we retrieved in step 2
output = ollama.generate(
  model = "llama3",
  prompt = prompt_template,
)

print(output['response'])
